# %%
import mne
from mne_bids import BIDSPath, read_raw_bids, print_dir_tree, make_report
import numpy as np
import os
from os.path import join
from bids import BIDSLayout

# %%
# Initialize the layout
data_path = os.path.join('/Users/alidzaye/Library/CloudStorage/OneDrive-SharedLibraries-Charité-UniversitätsmedizinBerlin/Interventional Cognitive Neuromodulation - Data/BIDS_Berlin_ECOG_LFP/rawdata')

# %%
layout = BIDSLayout(data_path)
layout
# Out:
# /Users/alidzaye/opt/anaconda3/envs/mne/lib/python3.9/site-packages/bids/layout/models.py:148: FutureWarning: The 'extension' entity currently excludes the leading dot ('.'). As of version 0.14.0, it will include the leading dot. To suppress this warning and include the leading dot, use `bids.config.set_option('extension_initial_dot', True)`.
#   warnings.warn("The 'extension' entity currently excludes the leading dot ('.'). "
# BIDS Layout: ...a/BIDS_Berlin_ECOG_LFP/rawdata | Subjects: 10 | Sessions: 35 | Runs: 25

# %%
layout.get_subjects()
# Out:
# ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010']

# %%
layout.get_session()
# Out:
# ['EcogLfpMedOff01',
#  'EcogLfpMedOff02',
#  'EcogLfpMedOff03',
#  'EcogLfpMedOn01',
#  'EcogLfpMedOn02',
#  'EcogLfpMedOn03']

# %%
layout.get_tasks()
# Out:
# ['BlockRotationL',
#  'BlockRotationR',
#  'BlockRotationWheel',
#  'ContinuousStopping',
#  'Evoked',
#  'Free',
#  'FreeDrawing',
#  'ReadRelaxMoveL',
#  'ReadRelaxMoveR',
#  'Rest',
#  'RestAndSpeech',
#  'SelfpacedForceWheel',
#  'SelfpacedHandFlipL',
#  'SelfpacedHandFlipR',
#  'SelfpacedHandTapL',
#  'SelfpacedRotationL',
#  'SelfpacedRotationR',
#  'SelfpacedSpeech',
#  'Speech',
#  'Transition',
#  'UPDRSIII',
#  'VigorStimL',
#  'VigorStimR',
#  'Visuomotor']

# %%
layout.get_acquisition()
# Out:
# ['StimOff',
#  'StimOffDopa00',
#  'StimOffDopa10',
#  'StimOffDopa15',
#  'StimOffDopa18',
#  'StimOffDopa20',
#  'StimOffDopa25',
#  'StimOffDopa30',
#  'StimOffDopa35',
#  'StimOffDopa40',
#  'StimOffDopa50',
#  'StimOffDopa55',
#  'StimOffDopa60',
#  'StimOffDopa65',
#  'StimOffDopa70',
#  'StimOffOn',
#  'StimOn']

# %%
# get Rest Data ON & OFF all subjects
files = layout.get(extension='vhdr', task='Rest',acquisition='StimOff', return_type='filename')
files_off = layout.get(extension='vhdr', task='Rest',acquisition='StimOff', session=['EcogLfpMedOff01','EcogLfpMedOff02', 'EcogLfpMedOff03'], return_type='filename')
files_on = layout.get(extension='vhdr', task='Rest', acquisition='StimOff', session=['EcogLfpMedOn01', 'EcogLfpMedOn01', 'EcogLfpMedOn01'],return_type='filename')

# %%
print(len(files))
print(len(files_off))
print(len(files_on))
# Out:
# 49
# 28
# 15

# %%
# get Rest Data ON & OFF all subjects
files2 = layout.get(extension='vhdr', task='Rest',acquisition='StimOff',subject='010', return_type='filename')
files2_off = layout.get(extension='vhdr', task='Rest',acquisition='StimOff',subject='010', session=['EcogLfpMedOff01','EcogLfpMedOff02', 'EcogLfpMedOff03'], return_type='filename')
files2_on = layout.get(extension='vhdr', task='Rest', acquisition='StimOff',subject='010', session=['EcogLfpMedOn01', 'EcogLfpMedOn02', 'EcogLfpMedOn03'],return_type='filename')

# %%
files2
# Out:
# ['/Users/alidzaye/Library/CloudStorage/OneDrive-SharedLibraries-Charité-UniversitätsmedizinBerlin/Interventional Cognitive Neuromodulation - Data/BIDS_Berlin_ECOG_LFP/rawdata/sub-010/ses-EcogLfpMedOff01/ieeg/sub-010_ses-EcogLfpMedOff01_task-Rest_acq-StimOff_run-1_ieeg.vhdr',
#  '/Users/alidzaye/Library/CloudStorage/OneDrive-SharedLibraries-Charité-UniversitätsmedizinBerlin/Interventional Cognitive Neuromodulation - Data/BIDS_Berlin_ECOG_LFP/rawdata/sub-010/ses-EcogLfpMedOn01/ieeg/sub-010_ses-EcogLfpMedOn01_task-Rest_acq-StimOff_run-1_ieeg.vhdr']

# %%
files2_off
# Out:
# ['/Users/alidzaye/Library/CloudStorage/OneDrive-SharedLibraries-Charité-UniversitätsmedizinBerlin/Interventional Cognitive Neuromodulation - Data/BIDS_Berlin_ECOG_LFP/rawdata/sub-010/ses-EcogLfpMedOff01/ieeg/sub-010_ses-EcogLfpMedOff01_task-Rest_acq-StimOff_run-1_ieeg.vhdr']

# %%
files2_on
# Out:
# ['/Users/alidzaye/Library/CloudStorage/OneDrive-SharedLibraries-Charité-UniversitätsmedizinBerlin/Interventional Cognitive Neuromodulation - Data/BIDS_Berlin_ECOG_LFP/rawdata/sub-010/ses-EcogLfpMedOn01/ieeg/sub-010_ses-EcogLfpMedOn01_task-Rest_acq-StimOff_run-1_ieeg.vhdr']

# %%
print_dir_tree(data_path, max_depth=4)
# Out:
# |rawdata/
# |--- .DS_Store
# |--- README
# |--- dataset_description.json
# |--- participants.json
# |--- participants.tsv
# |--- phenotype/
# |------ .DS_Store
# |------ UPDRS.xlsx
# |--- sub-001/
# |------ .DS_Store
# |------ ses-EphysMedOff01/
# |--------- .DS_Store
# |--------- sub-001_ses-EphysMedOff01_scans.json
# |--------- sub-001_ses-EphysMedOff01_scans.tsv
# |--------- ieeg/
# |------------ sub-001_ses-EphysMedOff01_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-001_ses-EphysMedOff01_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-001_ses-EphysMedOff01_task-BlockRotationR_acq-StimOffOn_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOff01_task-BlockRotationR_acq-StimOffOn_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOff01_task-BlockRotationR_acq-StimOffOn_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOff01_task-BlockRotationR_acq-StimOffOn_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOff01_task-BlockRotationR_acq-StimOffOn_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_channels.tsv
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.eeg
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.json
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-02_channels.tsv
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-02_ieeg.eeg
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-02_ieeg.json
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-02_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-02_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOff_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOff_run-01_events.tsv
# |------------ sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOff_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOn_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOn_run-01_events.tsv
# |------------ sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOn_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOn_run-01_ieeg.vmrk
# |------ ses-EphysMedOn01/
# |--------- .DS_Store
# |--------- sub-001_ses-EphysMedOn01_scans.json
# |--------- sub-001_ses-EphysMedOn01_scans.tsv
# |--------- anat/
# |--------- ieeg/
# |------------ sub-001_ses-EphysMedOn01_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-001_ses-EphysMedOn01_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-001_ses-EphysMedOn01_task-BlockRotationWheel_acq-StimOff_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOn01_task-BlockRotationWheel_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOn01_task-BlockRotationWheel_acq-StimOff_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOn01_task-BlockRotationWheel_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOn01_task-BlockRotationWheel_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOn01_task-FreeDrawing_acq-StimOff_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOn01_task-FreeDrawing_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOn01_task-FreeDrawing_acq-StimOff_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOn01_task-FreeDrawing_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOn01_task-FreeDrawing_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOn01_task-SelfpacedForceWheel_acq-StimOff_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOn01_task-SelfpacedForceWheel_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOn01_task-SelfpacedForceWheel_acq-StimOff_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOn01_task-SelfpacedForceWheel_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOn01_task-SelfpacedForceWheel_acq-StimOff_run-01_ieeg.vmrk
# |------ ses-EphysMedOn02/
# |--------- .DS_Store
# |--------- sub-001_ses-EphysMedOn02_scans.json
# |--------- sub-001_ses-EphysMedOn02_scans.tsv
# |--------- ieeg/
# |------------ sub-001_ses-EphysMedOn02_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-001_ses-EphysMedOn02_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-001_ses-EphysMedOn02_task-BlockRotationL_acq-StimOffOn_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOn02_task-BlockRotationL_acq-StimOffOn_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOn02_task-BlockRotationL_acq-StimOffOn_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOn02_task-BlockRotationL_acq-StimOffOn_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOn02_task-BlockRotationL_acq-StimOffOn_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOn02_task-ContinuousStopping_acq-StimOffOn_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOn02_task-ContinuousStopping_acq-StimOffOn_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOn02_task-ContinuousStopping_acq-StimOffOn_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOn02_task-ContinuousStopping_acq-StimOffOn_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOn02_task-ContinuousStopping_acq-StimOffOn_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_channels.tsv
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.json
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_channels.tsv
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.eeg
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.json
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.vhdr
# |------------ sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.vmrk
# |--- sub-002/
# |------ .DS_Store
# |------ ses-EphysMedOff01/
# |--------- .DS_Store
# |--------- sub-002_ses-EphysMedOff01_scans.json
# |--------- sub-002_ses-EphysMedOff01_scans.tsv
# |--------- ieeg/
# |------------ sub-002_ses-EphysMedOff01_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-002_ses-EphysMedOff01_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-002_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-002_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-002_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_channels.tsv
# |------------ sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.json
# |------------ sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-002_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-002_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------ ses-EphysMedOff02/
# |--------- .DS_Store
# |--------- sub-002_ses-EphysMedOff02_scans.json
# |--------- sub-002_ses-EphysMedOff02_scans.tsv
# |--------- ieeg/
# |------------ sub-002_ses-EphysMedOff02_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-002_ses-EphysMedOff02_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_channels.tsv
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_ieeg.json
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-02_channels.tsv
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-02_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-02_ieeg.json
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-02_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-02_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-03_channels.tsv
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-03_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-03_ieeg.json
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-03_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-03_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-02_channels.tsv
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-02_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-02_ieeg.json
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-02_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-03_channels.tsv
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-03_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-03_ieeg.json
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-03_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-03_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-002_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOff_run-01_events.tsv
# |------------ sub-002_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-002_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff02_task-Speech_acq-StimOff_run-01_channels.tsv
# |------------ sub-002_ses-EphysMedOff02_task-Speech_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff02_task-Speech_acq-StimOff_run-01_ieeg.json
# |------------ sub-002_ses-EphysMedOff02_task-Speech_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff02_task-Speech_acq-StimOff_run-01_ieeg.vmrk
# |------ ses-EphysMedOff03/
# |--------- .DS_Store
# |--------- sub-002_ses-EphysMedOff03_scans.json
# |--------- sub-002_ses-EphysMedOff03_scans.tsv
# |--------- ieeg/
# |------------ sub-002_ses-EphysMedOff03_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-002_ses-EphysMedOff03_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-02_channels.tsv
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-02_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-02_ieeg.json
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-02_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-03_channels.tsv
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-03_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-03_ieeg.json
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-03_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-03_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-04_channels.tsv
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-04_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-04_ieeg.json
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-04_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-04_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-01_channels.tsv
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-01_ieeg.json
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-02_channels.tsv
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-02_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-02_ieeg.json
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-02_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-02_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOff_run-01_events.tsv
# |------------ sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOn_run-01_channels.tsv
# |------------ sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOn_run-01_events.tsv
# |------------ sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.json
# |------------ sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.vmrk
# |--- sub-003/
# |------ .DS_Store
# |------ ses-EphysMedOff01/
# |--------- .DS_Store
# |--------- sub-003_ses-EphysMedOff01_scans.json
# |--------- sub-003_ses-EphysMedOff01_scans.tsv
# |--------- ieeg/
# |------------ .DS_Store
# |------------ sub-003_ses-EphysMedOff01_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-003_ses-EphysMedOff01_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-003_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-003_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-003_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-003_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-003_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_channels.tsv
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.eeg
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.json
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vmrk
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-03_channels.tsv
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-03_ieeg.eeg
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-03_ieeg.json
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-03_ieeg.vhdr
# |------------ sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-03_ieeg.vmrk
# |------------ sub-003_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-003_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_events.tsv
# |------------ sub-003_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-003_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-003_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-003_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_channels.tsv
# |------------ sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.json
# |------------ sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-02_channels.tsv
# |------------ sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-02_ieeg.eeg
# |------------ sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-02_ieeg.json
# |------------ sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-02_ieeg.vhdr
# |------------ sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-02_ieeg.vmrk
# |------ ses-EphysMedOn01/
# |--------- .DS_Store
# |--------- sub-003_ses-EphysMedOn01_scans.json
# |--------- sub-003_ses-EphysMedOn01_scans.tsv
# |--------- ieeg/
# |------------ sub-003_ses-EphysMedOn01_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-003_ses-EphysMedOn01_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-003_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-003_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-003_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-003_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-003_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------ ses-EphysMedOn02/
# |--------- .DS_Store
# |--------- sub-003_ses-EphysMedOn02_scans.json
# |--------- sub-003_ses-EphysMedOn02_scans.tsv
# |--------- ieeg/
# |------------ sub-003_ses-EphysMedOn02_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-003_ses-EphysMedOn02_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-003_ses-EphysMedOn02_task-RestAndSpeech_acq-StimOff_run-01_channels.tsv
# |------------ sub-003_ses-EphysMedOn02_task-RestAndSpeech_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-003_ses-EphysMedOn02_task-RestAndSpeech_acq-StimOff_run-01_ieeg.json
# |------------ sub-003_ses-EphysMedOn02_task-RestAndSpeech_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-003_ses-EphysMedOn02_task-RestAndSpeech_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-003_ses-EphysMedOn02_task-UPDRSIII_acq-StimOff_run-01_channels.tsv
# |------------ sub-003_ses-EphysMedOn02_task-UPDRSIII_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-003_ses-EphysMedOn02_task-UPDRSIII_acq-StimOff_run-01_ieeg.json
# |------------ sub-003_ses-EphysMedOn02_task-UPDRSIII_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-003_ses-EphysMedOn02_task-UPDRSIII_acq-StimOff_run-01_ieeg.vmrk
# |------ ses-EphysMedOn03/
# |--------- .DS_Store
# |--------- sub-003_ses-EphysMedOn03_scans.json
# |--------- sub-003_ses-EphysMedOn03_scans.tsv
# |--------- ieeg/
# |------------ sub-003_ses-EphysMedOn03_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-003_ses-EphysMedOn03_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-003_ses-EphysMedOn03_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-003_ses-EphysMedOn03_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-003_ses-EphysMedOn03_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-003_ses-EphysMedOn03_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-003_ses-EphysMedOn03_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-003_ses-EphysMedOn03_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-003_ses-EphysMedOn03_task-SelfpacedRotationR_acq-StimOff_run-01_events.tsv
# |------------ sub-003_ses-EphysMedOn03_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-003_ses-EphysMedOn03_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-003_ses-EphysMedOn03_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-003_ses-EphysMedOn03_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vmrk
# |--- sub-004/
# |------ .DS_Store
# |------ ses-EphysMedOff01/
# |--------- .DS_Store
# |--------- sub-004_ses-EphysMedOff01_scans.tsv
# |--------- ieeg/
# |------------ sub-004_ses-EphysMedOff01_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-004_ses-EphysMedOff01_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-004_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_channels.tsv
# |------------ sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.eeg
# |------------ sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.json
# |------------ sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_events.tsv
# |------------ sub-004_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_events.tsv
# |------------ sub-004_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOff01_task-Speech_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOff01_task-Speech_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOff01_task-Speech_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOff01_task-Speech_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOff01_task-Speech_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOff01_task-Transition_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOff01_task-Transition_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOff01_task-Transition_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOff01_task-Transition_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOff01_task-Transition_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOff01_task-Transition_acq-StimOff_run-02_channels.tsv
# |------------ sub-004_ses-EphysMedOff01_task-Transition_acq-StimOff_run-02_ieeg.eeg
# |------------ sub-004_ses-EphysMedOff01_task-Transition_acq-StimOff_run-02_ieeg.json
# |------------ sub-004_ses-EphysMedOff01_task-Transition_acq-StimOff_run-02_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOff01_task-Transition_acq-StimOff_run-02_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.vmrk
# |------ ses-EphysMedOn01/
# |--------- .DS_Store
# |--------- sub-004_ses-EphysMedOn01_scans.tsv
# |--------- ieeg/
# |------------ sub-004_ses-EphysMedOn01_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-004_ses-EphysMedOn01_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-004_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_channels.tsv
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.json
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_channels.tsv
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_ieeg.json
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-04_channels.tsv
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-04_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-04_ieeg.json
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-04_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-04_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_events.tsv
# |------------ sub-004_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_events.tsv
# |------------ sub-004_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn01_task-Speech_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOn01_task-Speech_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn01_task-Speech_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOn01_task-Speech_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn01_task-Speech_acq-StimOff_run-01_ieeg.vmrk
# |------ ses-EphysMedOn02/
# |--------- .DS_Store
# |--------- sub-004_ses-EphysMedOn02_scans.tsv
# |--------- ieeg/
# |------------ sub-004_ses-EphysMedOn02_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-004_ses-EphysMedOn02_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOn_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOn_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_channels.tsv
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.json
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_channels.tsv
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.eeg
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.json
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.vhdr
# |------------ sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.vmrk
# |--- sub-005/
# |------ .DS_Store
# |------ ses-EphysMedOff01/
# |--------- .DS_Store
# |--------- sub-005_ses-EphysMedOff01_scans.tsv
# |--------- ieeg/
# |------------ sub-005_ses-EphysMedOff01_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-005_ses-EphysMedOff01_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-005_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_channels.tsv
# |------------ sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.json
# |------------ sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_events.tsv
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_events.tsv
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedSpeech_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedSpeech_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedSpeech_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedSpeech_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff01_task-SelfpacedSpeech_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.vmrk
# |------ ses-EphysMedOff02/
# |--------- .DS_Store
# |--------- sub-005_ses-EphysMedOff02_scans.tsv
# |--------- ieeg/
# |------------ sub-005_ses-EphysMedOff02_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-005_ses-EphysMedOff02_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-005_ses-EphysMedOff02_task-BlockRotationL_acq-StimOn_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff02_task-BlockRotationL_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff02_task-BlockRotationL_acq-StimOn_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff02_task-BlockRotationL_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff02_task-BlockRotationL_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff02_task-BlockRotationR_acq-StimOn_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff02_task-BlockRotationR_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff02_task-BlockRotationR_acq-StimOn_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff02_task-BlockRotationR_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff02_task-BlockRotationR_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOn_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOn_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff02_task-Rest_acq-StimOn_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff02_task-Rest_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff02_task-Rest_acq-StimOn_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff02_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff02_task-Rest_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff02_task-SelfpacedRotationL_acq-StimOn_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff02_task-SelfpacedRotationL_acq-StimOn_run-01_events.tsv
# |------------ sub-005_ses-EphysMedOff02_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff02_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff02_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff02_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOn_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOn_run-01_events.tsv
# |------------ sub-005_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.vmrk
# |------ ses-EphysMedOn01/
# |--------- .DS_Store
# |--------- sub-005_ses-EphysMedOn01_scans.tsv
# |--------- ieeg/
# |------------ sub-005_ses-EphysMedOn01_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-005_ses-EphysMedOn01_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-005_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_events.tsv
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_events.tsv
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedSpeech_acq-StimOff_run-01_channels.tsv
# |------------ sub-005_ses-EphysMedOn01_task-SelfpacedSpeech_acq-StimOff_run-01_ieeg.eeg
# ...
# |------------ sub-006_ses-EphysMedOn02_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-006_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-006_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-006_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-006_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-006_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-006_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_channels.tsv
# |------------ sub-006_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-006_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.json
# |------------ sub-006_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-006_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-006_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-006_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-006_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-006_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-006_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-006_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOn_run-01_channels.tsv
# |------------ sub-006_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-006_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.json
# |------------ sub-006_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-006_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.vmrk
# |--- sub-007/
# |------ .DS_Store
# |------ ses-EphysMedOff01/
# |--------- .DS_Store
# |--------- sub-007_ses-EphysMedOff01_scans.tsv
# |--------- ieeg/
# |------------ sub-007_ses-EphysMedOff01_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-007_ses-EphysMedOff01_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-007_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOff01_task-BlockRotationL_acq-StimOn_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOff01_task-BlockRotationL_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOff01_task-BlockRotationL_acq-StimOn_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOff01_task-BlockRotationL_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOff01_task-BlockRotationL_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOff01_task-ReadRelaxMoveL_acq-StimOff_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOff01_task-ReadRelaxMoveL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOff01_task-ReadRelaxMoveL_acq-StimOff_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOff01_task-ReadRelaxMoveL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOff01_task-ReadRelaxMoveL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOn_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.vmrk
# |------ ses-EphysMedOff02/
# |--------- .DS_Store
# |--------- sub-007_ses-EphysMedOff02_scans.tsv
# |--------- ieeg/
# |------------ sub-007_ses-EphysMedOff02_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-007_ses-EphysMedOff02_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-007_ses-EphysMedOff02_task-VigorStimR_acq-StimOn_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOff02_task-VigorStimR_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOff02_task-VigorStimR_acq-StimOn_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOff02_task-VigorStimR_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOff02_task-VigorStimR_acq-StimOn_run-01_ieeg.vmrk
# |------ ses-EphysMedOn01/
# |--------- .DS_Store
# |--------- sub-007_ses-EphysMedOn01_scans.tsv
# |--------- ieeg/
# |------------ sub-007_ses-EphysMedOn01_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-007_ses-EphysMedOn01_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_channels.tsv
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.eeg
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.json
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_channels.tsv
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_ieeg.eeg
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_ieeg.json
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-02_channels.tsv
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-02_ieeg.eeg
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-02_ieeg.json
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-02_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-02_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-03_channels.tsv
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-03_ieeg.eeg
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-03_ieeg.json
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-03_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOn01_task-Rest_acq-StimOn_run-03_ieeg.vmrk
# |------ ses-EphysMedOn02/
# |--------- .DS_Store
# |--------- sub-007_ses-EphysMedOn02_scans.tsv
# |--------- ieeg/
# |------------ sub-007_ses-EphysMedOn02_space-MNI152NLin2009bAsym_coordsystem.json
# |------------ sub-007_ses-EphysMedOn02_space-MNI152NLin2009bAsym_electrodes.tsv
# |------------ sub-007_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOff_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOn02_task-VigorStimL_acq-StimOn_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOn02_task-VigorStimL_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOn02_task-VigorStimL_acq-StimOn_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOn02_task-VigorStimL_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOn02_task-VigorStimL_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-007_ses-EphysMedOn02_task-VigorStimR_acq-StimOn_run-01_channels.tsv
# |------------ sub-007_ses-EphysMedOn02_task-VigorStimR_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-007_ses-EphysMedOn02_task-VigorStimR_acq-StimOn_run-01_ieeg.json
# |------------ sub-007_ses-EphysMedOn02_task-VigorStimR_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-007_ses-EphysMedOn02_task-VigorStimR_acq-StimOn_run-01_ieeg.vmrk
# |--- sub-008/
# |------ .DS_Store
# |------ ses-EphysMedOff01/
# |--------- .DS_Store
# |--------- sub-008_ses-EphysMedOff01_scans.tsv
# |--------- ieeg/
# |------------ sub-008_ses-EphysMedOff01_coordsystem.json
# |------------ sub-008_ses-EphysMedOff01_electrodes.tsv
# |------------ sub-008_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-008_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-008_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-008_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-008_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-008_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_channels.tsv
# |------------ sub-008_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-008_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.json
# |------------ sub-008_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-008_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-008_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-008_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-008_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-008_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-008_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-008_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOn_run-01_channels.tsv
# |------------ sub-008_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-008_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.json
# |------------ sub-008_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-008_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-008_ses-EphysMedOff01_task-VigorStimR_acq-StimOn_run-01_channels.tsv
# |------------ sub-008_ses-EphysMedOff01_task-VigorStimR_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-008_ses-EphysMedOff01_task-VigorStimR_acq-StimOn_run-01_ieeg.json
# |------------ sub-008_ses-EphysMedOff01_task-VigorStimR_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-008_ses-EphysMedOff01_task-VigorStimR_acq-StimOn_run-01_ieeg.vmrk
# |------ ses-EphysMedOn01/
# |--------- .DS_Store
# |--------- sub-008_ses-EphysMedOn01_scans.tsv
# |--------- ieeg/
# |------------ sub-008_ses-EphysMedOn01_coordsystem.json
# |------------ sub-008_ses-EphysMedOn01_electrodes.tsv
# |------------ sub-008_ses-EphysMedOn01_task-ReadRelaxMoveR_acq-StimOff_run-01_channels.tsv
# |------------ sub-008_ses-EphysMedOn01_task-ReadRelaxMoveR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-008_ses-EphysMedOn01_task-ReadRelaxMoveR_acq-StimOff_run-01_ieeg.json
# |------------ sub-008_ses-EphysMedOn01_task-ReadRelaxMoveR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-008_ses-EphysMedOn01_task-ReadRelaxMoveR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_channels.tsv
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.json
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_channels.tsv
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.eeg
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.json
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.vmrk
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_channels.tsv
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.json
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-008_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.vmrk
# |------------ sub-008_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# |------------ sub-008_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.eeg
# |------------ sub-008_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# |------------ sub-008_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# |------------ sub-008_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vmrk
# |------------ sub-008_ses-EphysMedOn01_task-VigorStimR_acq-StimOn_run-01_channels.tsv
# |------------ sub-008_ses-EphysMedOn01_task-VigorStimR_acq-StimOn_run-01_ieeg.eeg
# |------------ sub-008_ses-EphysMedOn01_task-VigorStimR_acq-StimOn_run-01_ieeg.json
# |------------ sub-008_ses-EphysMedOn01_task-VigorStimR_acq-StimOn_run-01_ieeg.vhdr
# |------------ sub-008_ses-EphysMedOn01_task-VigorStimR_acq-StimOn_run-01_ieeg.vmrk

# %% [markdown]
# # Merge data

# %%
# read in data value 
#df_rmd = pd.read_csv('mean_burst_duration_1.csv')
#df_rmd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ab03d6e7cf7a> in <module>
#       1 # read in data value
# ----> 2 df_rmd = pd.read_csv('mean_burst_duration_1.csv')
#       3 df_rmd
#
# NameError: name 'pd' is not defined

# %%
#df_row = df_rmd.values[3]
#value = df_row[1]
#value
